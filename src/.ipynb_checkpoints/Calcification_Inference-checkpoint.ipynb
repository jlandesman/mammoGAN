# %%
# %matplotlib inline
# %precision %.2f
from keras.models import load_model
from keras.models import Sequential
import cv2
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from PIL import Image
import os
from skimage.util import view_as_windows

model = load_model('/home/jlandesman/model_history/weights-improvement-13-0.65.hdf5') ## can run only  inference, for training call model.compile
np.set_printoptions(precision = 2, suppress=True)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.5/dist-packages/keras/models.py:252: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
def get_patches(im, step_size = 20, dimensions = [256, 256]):
    '''
    Return sliding windows along the breast, moving STEP_SIZE pixels at a time.
    
    IMPORTANT: np.reshape() does not guarantee a copy isn't made - this leads to memory errors
    
    params:
        step_size: the stride by which the window jumps
        dimemsions: the dimensions of the patch
    '''
    patches = view_as_windows(im,dimensions,step=step_size)
    patches = patches.reshape([-1, 256, 256])
    
    return patches

def normalize(img):
    normalized_img = ((img - np.min(img))/(np.max(img) - np.min(img)))*255
    return normalized_img

# %%
calc_test_files = os.listdir('/mnt/disks/patches/cbis-ddsm/calc_test_full_mammogram/')

for file in calc_test_files:
    if not os.path.exists(os.path.join('/home/jlandesman/test_images', file + '/test_images/')):
        os.mkdir(os.path.join('/home/jlandesman/test_images', file + '/test_images/'))
    
    im = Image.open(os.path.join('/mnt/disks/patches/cbis-ddsm/calc_test_full_mammogram/', file))
    im_patches = get_patches(np.asarray(im), step_size = 100)
    
    for number, image in enumerate(im_patches):
        image = normalize(image)
        path = os.path.join('/home/jlandesman/test_images/', file + '/test_images/' + file)
        cv2.imwrite(path + '_' + str(number) + '.png', image, [cv2.IMWRITE_PNG_COMPRESSION, 0])
    
    print("Finished processing ", file)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# Finished processing  Calc-Test_P_00368_LEFT_CC
# Finished processing  Calc-Test_P_01728_LEFT_CC
# Finished processing  Calc-Test_P_02159_LEFT_MLO
# Finished processing  Calc-Test_P_02432_LEFT_CC
# Finished processing  Calc-Test_P_01030_RIGHT_MLO
# Finished processing  Calc-Test_P_01535_LEFT_CC
# Finished processing  Calc-Test_P_00402_RIGHT_MLO
# Finished processing  Calc-Test_P_00038_RIGHT_CC
# Finished processing  Calc-Test_P_01390_RIGHT_MLO
# Finished processing  Calc-Test_P_01883_RIGHT_MLO
# Finished processing  Calc-Test_P_01872_LEFT_MLO
# Finished processing  Calc-Test_P_01547_LEFT_CC
# Finished processing  Calc-Test_P_01882_LEFT_MLO
# Finished processing  Calc-Test_P_01211_LEFT_CC
# Finished processing  Calc-Test_P_01643_RIGHT_MLO
# Finished processing  Calc-Test_P_00352_LEFT_MLO
# Finished processing  Calc-Test_P_00681_LEFT_CC
# Finished processing  Calc-Test_P_00214_RIGHT_MLO
# Finished processing  Calc-Test_P_00643_LEFT_MLO
# Finished processing  Calc-Test_P_02432_LEFT_MLO
# Finished processing  Calc-Test_P_00649_LEFT_MLO
# Finished processing  Calc-Test_P_00905_RIGHT_MLO
# Finished processing  Calc-Test_P_00331_LEFT_MLO
# Finished processing  Calc-Test_P_01882_LEFT_CC
# Finished processing  Calc-Test_P_01460_LEFT_MLO
# Finished processing  Calc-Test_P_01419_LEFT_MLO
# Finished processing  Calc-Test_P_02198_LEFT_CC
# Finished processing  Calc-Test_P_00353_LEFT_CC
# Finished processing  Calc-Test_P_01534_LEFT_CC
# Finished processing  Calc-Test_P_01536_RIGHT_CC
# Finished processing  Calc-Test_P_00562_LEFT_CC
# Finished processing  Calc-Test_P_00663_RIGHT_MLO
# Finished processing  Calc-Test_P_00127_RIGHT_CC
# Finished processing  Calc-Test_P_01635_RIGHT_MLO
# Finished processing  Calc-Test_P_01861_LEFT_MLO
# Finished processing  Calc-Test_P_01390_RIGHT_CC
# Finished processing  Calc-Test_P_00681_LEFT_MLO
# Finished processing  Calc-Test_P_01318_LEFT_MLO
# Finished processing  Calc-Test_P_00843_RIGHT_CC
# Finished processing  Calc-Test_P_01602_RIGHT_CC
# Finished processing  Calc-Test_P_00397_LEFT_CC
# Finished processing  Calc-Test_P_01414_RIGHT_MLO
# Finished processing  Calc-Test_P_01803_RIGHT_CC
# Finished processing  Calc-Test_P_01883_RIGHT_CC
# Finished processing  Calc-Test_P_02501_RIGHT_CC
# Finished processing  Calc-Test_P_00795_LEFT_MLO
# Finished processing  Calc-Test_P_01743_RIGHT_CC
# Finished processing  Calc-Test_P_01414_RIGHT_CC
# Finished processing  Calc-Test_P_01845_RIGHT_MLO
# Finished processing  Calc-Test_P_00100_RIGHT_MLO
# Finished processing  Calc-Test_P_01237_LEFT_CC
# Finished processing  Calc-Test_P_00562_LEFT_MLO
# Finished processing  Calc-Test_P_00906_LEFT_CC
# Finished processing  Calc-Test_P_01352_LEFT_MLO
# Finished processing  Calc-Test_P_01621_LEFT_MLO
# Finished processing  Calc-Test_P_00202_RIGHT_MLO
# Finished processing  Calc-Test_P_01872_LEFT_CC
# Finished processing  Calc-Test_P_00857_RIGHT_MLO
# Finished processing  Calc-Test_P_01030_RIGHT_CC
# Finished processing  Calc-Test_P_00466_LEFT_MLO
# Finished processing  Calc-Test_P_01490_LEFT_MLO
# Finished processing  Calc-Test_P_00827_RIGHT_CC
# Finished processing  Calc-Test_P_00164_RIGHT_CC
# Finished processing  Calc-Test_P_01460_LEFT_CC
# Finished processing  Calc-Test_P_01670_LEFT_MLO
# Finished processing  Calc-Test_P_01407_RIGHT_CC
# Finished processing  Calc-Test_P_00325_RIGHT_MLO
# Finished processing  Calc-Test_P_00497_LEFT_CC
# Finished processing  Calc-Test_P_00163_LEFT_MLO
# Finished processing  Calc-Test_P_02139_LEFT_CC
# Finished processing  Calc-Test_P_02420_RIGHT_CC
# Finished processing  Calc-Test_P_01465_LEFT_MLO
# Finished processing  Calc-Test_P_01042_RIGHT_MLO
# Finished processing  Calc-Test_P_01148_RIGHT_MLO
# Finished processing  Calc-Test_P_00646_LEFT_MLO
# Finished processing  Calc-Test_P_00140_LEFT_MLO
# Finished processing  Calc-Test_P_01211_RIGHT_MLO
# Finished processing  Calc-Test_P_01022_LEFT_MLO
# Finished processing  Calc-Test_P_00141_LEFT_CC
# Finished processing  Calc-Test_P_00646_LEFT_CC
# Finished processing  Calc-Test_P_00678_LEFT_CC
# Finished processing  Calc-Test_P_00790_RIGHT_CC
# Finished processing  Calc-Test_P_01320_LEFT_MLO
# Finished processing  Calc-Test_P_00589_LEFT_MLO
# Finished processing  Calc-Test_P_00537_RIGHT_MLO
# Finished processing  Calc-Test_P_02275_LEFT_MLO
# Finished processing  Calc-Test_P_00195_LEFT_MLO
# Finished processing  Calc-Test_P_00570_LEFT_MLO
# Finished processing  Calc-Test_P_01154_LEFT_MLO
# Finished processing  Calc-Test_P_01711_RIGHT_CC
# Finished processing  Calc-Test_P_01643_RIGHT_CC
# Finished processing  Calc-Test_P_01407_LEFT_CC
# Finished processing  Calc-Test_P_01058_LEFT_MLO
# Finished processing  Calc-Test_P_01272_LEFT_MLO
# Finished processing  Calc-Test_P_00140_RIGHT_CC
# Finished processing  Calc-Test_P_01773_RIGHT_CC
# Finished processing  Calc-Test_P_01868_LEFT_MLO
# Finished processing  Calc-Test_P_00649_LEFT_CC
# Finished processing  Calc-Test_P_02464_RIGHT_MLO
# Finished processing  Calc-Test_P_01303_LEFT_CC
# Finished processing  Calc-Test_P_01460_RIGHT_CC
# Finished processing  Calc-Test_P_00879_RIGHT_CC
# Finished processing  Calc-Test_P_00299_RIGHT_CC
# Finished processing  Calc-Test_P_01536_RIGHT_MLO
# Finished processing  Calc-Test_P_00077_RIGHT_MLO
# Finished processing  Calc-Test_P_01670_LEFT_CC
# Finished processing  Calc-Test_P_02198_LEFT_MLO
# Finished processing  Calc-Test_P_01352_LEFT_CC
# Finished processing  Calc-Test_P_00974_RIGHT_MLO
# Finished processing  Calc-Test_P_01058_LEFT_CC
# Finished processing  Calc-Test_P_01711_RIGHT_MLO
# Finished processing  Calc-Test_P_01845_RIGHT_CC
# Finished processing  Calc-Test_P_01752_LEFT_MLO
# Finished processing  Calc-Test_P_01562_LEFT_CC
# Finished processing  Calc-Test_P_01842_LEFT_MLO
# Finished processing  Calc-Test_P_00608_LEFT_MLO
# Finished processing  Calc-Test_P_00460_LEFT_CC
# Finished processing  Calc-Test_P_00679_LEFT_CC
# Finished processing  Calc-Test_P_01752_LEFT_CC
# Finished processing  Calc-Test_P_01460_RIGHT_MLO
# Finished processing  Calc-Test_P_00344_LEFT_MLO

# %%
from collections import defaultdict
train_datagen = ImageDataGenerator()
PATH_TO_FILES = '/home/jlandesman/test_images/'

results_list = defaultdict(float)

for file in calc_test_files:
    send_imgs =  train_datagen.flow_from_directory(os.path.join(PATH_TO_FILES, file))
    results = model.predict_generator(send_imgs, 1)
    results_list[file] = np.argmax(results, axis=-1)
    print('Finished processing: ', file)
# Out:
# Found 1075 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00368_LEFT_CC
# Found 1222 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01728_LEFT_CC
# Found 2394 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_02159_LEFT_MLO
# Found 1400 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_02432_LEFT_CC
# Found 1036 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01030_RIGHT_MLO
# Found 1300 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01535_LEFT_CC
# Found 1247 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00402_RIGHT_MLO
# Found 1125 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_
images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01635_RIGHT_CC
# Found 1325 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01157_RIGHT_MLO
# Found 1219 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01538_RIGHT_MLO
# Found 1290 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01867_LEFT_MLO
# Found 1378 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00223_LEFT_MLO
# Found 1204 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00214_LEFT_CC
# Found 1247 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01211_LEFT_MLO
# Found 1120 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00646_LEFT_CC
# Found 1830 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00678_LEFT_CC
# Found 1215 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00790_RIGHT_CC
# Found 1378 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01320_LEFT_MLO
# Found 1118 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00589_LEFT_MLO
# Found 1275 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00537_RIGHT_MLO
# Found 2535 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_02275_LEFT_MLO
# Found 1378 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00195_LEFT_MLO
# Found 1350 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00570_LEFT_MLO
# Found 1643 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01154_LEFT_MLO
# Found 1078 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01711_RIGHT_CC
# Found 1188 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01643_RIGHT_CC
# Found 1188 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01407_LEFT_CC
# Found 1134 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01058_LEFT_MLO
# Found 2080 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01272_LEFT_MLO
# Found 1204 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00140_RIGHT_CC
# Found 1710 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01773_RIGHT_CC
# Found 1118 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01868_LEFT_MLO
# Found 2508 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00649_LEFT_CC
# Found 3168 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_02464_RIGHT_MLO
# Found 969 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01303_LEFT_CC
# Found 1176 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01460_RIGHT_CC
# Found 1300 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00879_RIGHT_CC
# Found 1947 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00299_RIGHT_CC
# Found 833 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01536_RIGHT_MLO
# Found 1276 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00077_RIGHT_MLO
# Found 1025 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01670_LEFT_CC
# Found 1428 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_02198_LEFT_MLO
# Found 2090 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01352_LEFT_CC
# Found 1860 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00974_RIGHT_MLO
# Found 1161 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01058_LEFT_CC
# Found 1325 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01711_RIGHT_MLO
# Found 1012 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01845_RIGHT_CC
# Found 1060 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01752_LEFT_MLO
# Found 1944 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01562_LEFT_CC
# Found 2331 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01842_LEFT_MLO
# Found 1950 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00608_LEFT_MLO
# Found 1204 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00460_LEFT_CC
# Found 1204 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00679_LEFT_CC
# Found 840 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01752_LEFT_CC
# Found 1176 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_01460_RIGHT_MLO
# Found 1161 images belonging to 1 classes.
# Finished processing:  Calc-Test_P_00344_LEFT_MLO

# %%
import pandas as pd

# %%
saveable_list = defaultdict(list)
for k, v in results_list.items():
    saveable_list[k] = list(v)

# %%
with open ('results_list_2.pkl', 'wb') as f:
    pickle.dump(saveable_list, f)

# %%
import csv
with open('results_list.csv') as f:

# %%
import json

# writing
json.dump(saveable_list, open('/home/jlandesman/test_images/results.json', 'w'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-715cb8bbec46> in <module>()
#       2
#       3 # writing
# ----> 4 json.dump(saveable_list, open('/home/jlandesman/test_images/results.json', 'w'))
#
# /usr/lib/python3.5/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     176     # could accelerate with writelines in some versions of Python, at
#     177     # a debuggability cost
# --> 178     for chunk in iterable:
#     179         fp.write(chunk)
#     180
#
# /usr/lib/python3.5/json/encoder.py in _iterencode(o, _current_indent_level)
#     427             yield from _iterencode_list(o, _current_indent_level)
#     428         elif isinstance(o, dict):
# --> 429             yield from _iterencode_dict(o, _current_indent_level)
#     430         else:
#     431             if markers is not None:
#
# /usr/lib/python3.5/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     401                 else:
#     402                     chunks = _iterencode(value, _current_indent_level)
# --> 403                 yield from chunks
#     404         if newline_indent is not None:
#     405             _current_indent_level -= 1
#
# /usr/lib/python3.5/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     322                 else:
#     323                     chunks = _iterencode(value, _current_indent_level)
# --> 324                 yield from chunks
#     325         if newline_indent is not None:
#     326             _current_indent_level -= 1
#
# /usr/lib/python3.5/json/encoder.py in _iterencode(o, _current_indent_level)
#     434                     raise ValueError("Circular reference detected")
#     435                 markers[markerid] = o
# --> 436             o = _default(o)
#     437             yield from _iterencode(o, _current_indent_level)
#     438             if markers is not None:
#
# /usr/lib/python3.5/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(repr(o) + " is not JSON serializable")
#     180
#     181     def encode(self, o):
#
# TypeError: 3 is not JSON serializable

# %%
import pickle

# %%
from statistics import mode
for k, v in results_list.items():
    v = [i for i in v if i < 3]
    try:
        print(k, mode(v,))
    except:
        print('k, two most common values')
# Out:
# Calc-Test_P_00678_LEFT_CC 2
# Calc-Test_P_00150_RIGHT_MLO 2
# Calc-Test_P_02498_RIGHT_CC 2
# Calc-Test_P_02139_LEFT_CC 2
# Calc-Test_P_00686_RIGHT_MLO 2
# Calc-Test_P_01867_LEFT_MLO 2
# Calc-Test_P_01414_RIGHT_CC 2
# Calc-Test_P_01476_RIGHT_CC 2
# Calc-Test_P_00485_LEFT_MLO 2
# Calc-Test_P_01872_LEFT_CC 2
# Calc-Test_P_00497_LEFT_MLO 2
# Calc-Test_P_00857_RIGHT_CC 2
# Calc-Test_P_00790_RIGHT_MLO 2
# Calc-Test_P_00352_LEFT_MLO 0
# Calc-Test_P_00331_LEFT_CC 2
# Calc-Test_P_00843_RIGHT_MLO 2
# Calc-Test_P_00331_LEFT_MLO 2
# Calc-Test_P_00353_LEFT_CC 2
# Calc-Test_P_01318_LEFT_MLO 2
# Calc-Test_P_00390_RIGHT_MLO 2
# Calc-Test_P_00163_LEFT_MLO 2
# Calc-Test_P_01022_LEFT_MLO 2
# Calc-Test_P_00906_LEFT_MLO 2
# Calc-Test_P_01743_RIGHT_MLO 2
# Calc-Test_P_01058_LEFT_CC 2
# Calc-Test_P_01476_RIGHT_MLO 2
# Calc-Test_P_01490_LEFT_MLO 2
# Calc-Test_P_01538_RIGHT_MLO 2
# Calc-Test_P_00789_LEFT_MLO 2
# Calc-Test_P_01211_LEFT_MLO 2
# Calc-Test_P_00460_LEFT_MLO 0
# k, two most common values
# Calc-Test_P_00497_LEFT_CC 2
# Calc-Test_P_01157_RIGHT_CC 2
# Calc-Test_P_01390_RIGHT_MLO 2
# Calc-Test_P_00180_LEFT_MLO 2
# Calc-Test_P_01460_LEFT_MLO 1
# Calc-Test_P_00905_RIGHT_CC 2
# Calc-Test_P_00164_RIGHT_CC 2
# Calc-Test_P_00100_RIGHT_MLO 2
# Calc-Test_P_01867_LEFT_CC 2
# Calc-Test_P_00077_LEFT_CC 2
# Calc-Test_P_01237_LEFT_CC 0
# Calc-Test_P_00140_LEFT_MLO 2
# Calc-Test_P_00562_RIGHT_CC 2
# Calc-Test_P_01711_RIGHT_CC 2
# Calc-Test_P_01224_RIGHT_CC 2
# Calc-Test_P_00214_LEFT_CC 0
# Calc-Test_P_01845_RIGHT_CC 2
# Calc-Test_P_01562_LEFT_MLO 2
# Calc-Test_P_00038_RIGHT_MLO 2
# Calc-Test_P_01419_LEFT_MLO 0
# Calc-Test_P_00140_LEFT_CC 2
# Calc-Test_P_01399_RIGHT_CC 2
# Calc-Test_P_00244_RIGHT_MLO 2
# Calc-Test_P_00843_RIGHT_CC 2
# Calc-Test_P_01211_RIGHT_MLO 2
# Calc-Test_P_01834_LEFT_MLO 2
# Calc-Test_P_00579_LEFT_MLO 2
# Calc-Test_P_01803_RIGHT_CC 2
# Calc-Test_P_00906_LEFT_CC 2
# Calc-Test_P_00679_LEFT_CC 2
# Calc-Test_P_02139_LEFT_MLO 2
# Calc-Test_P_00663_RIGHT_CC 2
# Calc-Test_P_00403_RIGHT_MLO 2
# Calc-Test_P_00774_RIGHT_CC 2
# Calc-Test_P_02275_LEFT_CC 2
# Calc-Test_P_00681_LEFT_MLO 2
# Calc-Test_P_01224_RIGHT_MLO 2
# Calc-Test_P_01092_LEFT_CC 2
# Calc-Test_P_01535_LEFT_CC 2
# Calc-Test_P_01643_RIGHT_CC 0
# Calc-Test_P_01670_LEFT_CC 2
# Calc-Test_P_01868_LEFT_MLO 2
# Calc-Test_P_01415_RIGHT_MLO 2
# Calc-Test_P_00679_LEFT_MLO 2
# Calc-Test_P_01092_LEFT_MLO 2
# Calc-Test_P_00485_LEFT_CC 2
# Calc-Test_P_01502_LEFT_MLO 2
# Calc-Test_P_02501_RIGHT_MLO 2
# Calc-Test_P_00827_RIGHT_MLO 2
# Calc-Test_P_00344_LEFT_MLO 2
# Calc-Test_P_00811_LEFT_CC 2
# Calc-Test_P_02176_RIGHT_MLO 2
# Calc-Test_P_00368_LEFT_MLO 2
# Calc-Test_P_00495_RIGHT_CC 2
# Calc-Test_P_01042_RIGHT_CC 2
# Calc-Test_P_00397_LEFT_CC 2
# Calc-Test_P_00974_RIGHT_MLO 2
# Calc-Test_P_00195_LEFT_CC 2
# Calc-Test_P_00774_RIGHT_MLO 2
# Calc-Test_P_01407_LEFT_CC 2
# Calc-Test_P_00180_LEFT_CC 2

# %%
pickle.dump(results_list, 'results_list.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3da6aa459b56> in <module>()
# ----> 1 pickle.dump(results_list, 'results_list.pkl')
#
# TypeError: file must have a 'write' attribute

# %%
# !ls /home/jlandesman/test_images/

# %%
send_imgs =  train_datagen.flow_from_directory('/home/jlandesman/test_images')

# %%
results = model.predict_generator(send_imgs,1),

# %%
max_prob = np.argmax(results, axis=-1)

# %%
max_prob[max_prob != 3]

# %%
for number, j in enumerate(np.argmax(results, axis=-1)):
    print (number, j)

# %%
results[17]

# %%
import pandas as pd

# %%
df = pd.read_csv('/mnt/disks/patches/cbis-ddsm/calc_case_description_test_set.csv')

# %%
df.head()
# Out:
#   patient_id  breast_density   side view  abn_num             calc_type  \
# 0    P_00038               2   LEFT   CC        1  PUNCTATE-PLEOMORPHIC
# 1    P_00038               2   LEFT  MLO        1  PUNCTATE-PLEOMORPHIC
# 2    P_00038               2  RIGHT   CC        1              VASCULAR
# 3    P_00038               2  RIGHT   CC        2              VASCULAR
# 4    P_00038               2  RIGHT  MLO        1              VASCULAR
#
#   calc_distribution  assessment                pathology  subtlety  \
# 0         CLUSTERED           4                   BENIGN         2
# 1         CLUSTERED           4                   BENIGN         2
# 2               NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 3               NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 4               NaN           2  BENIGN_WITHOUT_CALLBACK         5
#
#                                          od_img_path  \
# 0  Calc-Test_P_00038_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1  Calc-Test_P_00038_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2  Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 3  Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 4  Calc-Test_P_00038_RIGHT_MLO/1.3.6.1.4.1.9590.1...
#
#                                         od_crop_path  \
# 0  Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1  Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2  Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3  Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4  Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
#
#                                            mask_path
# 0  Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1  Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2  Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3  Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4  Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...

# %%
pd.options.display.max_rows = 999
df[['patient_id', 'side','view','pathology']]
# Out:
#     patient_id   side view                pathology
# 0      P_00038   LEFT   CC                   BENIGN
# 1      P_00038   LEFT  MLO                   BENIGN
# 2      P_00038  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 3      P_00038  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 4      P_00038  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 5      P_00038  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 6      P_00041   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 7      P_00041   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 8      P_00077   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 9      P_00077   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 10     P_00077  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 11     P_00077  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 12     P_00077  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 13     P_00077  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 14     P_00100  RIGHT   CC                   BENIGN
# 15     P_00100  RIGHT  MLO                   BENIGN
# 16     P_00127  RIGHT   CC                MALIGNANT
# 17     P_00127  RIGHT  MLO                MALIGNANT
# 18     P_00132   LEFT  MLO                   BENIGN
# 19     P_00140   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 20     P_00140   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 21     P_00140   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 22     P_00140   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 23     P_00140  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 24     P_00140  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 25     P_00140  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 26     P_00140  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 27     P_00141   LEFT   CC                   BENIGN
# 28     P_00141   LEFT  MLO                   BENIGN
# 29     P_00150  RIGHT  MLO                MALIGNANT
# 30     P_00163   LEFT   CC                   BENIGN
# 31     P_00163   LEFT  MLO                   BENIGN
# 32     P_00164  RIGHT   CC                MALIGNANT
# 33     P_00180   LEFT   CC                   BENIGN
# 34     P_00180   LEFT  MLO                   BENIGN
# 35     P_00195   LEFT   CC                   BENIGN
# 36     P_00195   LEFT  MLO                   BENIGN
# 37     P_00202  RIGHT   CC                MALIGNANT
# 38     P_00202  RIGHT  MLO                MALIGNANT
# 39     P_00214   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 40     P_00214   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 41     P_00214   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 42     P_00214   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 43     P_00214  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 44     P_00223   LEFT  MLO                   BENIGN
# 45     P_00244  RIGHT  MLO                MALIGNANT
# 46     P_00246  RIGHT  MLO                   BENIGN
# 47     P_00257  RIGHT   CC                   BENIGN
# 48     P_00257  RIGHT  MLO                   BENIGN
# 49     P_00299   LEFT  MLO                MALIGNANT
# 50     P_00299  RIGHT   CC                MALIGNANT
# 51     P_00299  RIGHT  MLO                MALIGNANT
# 52     P_00315   LEFT  MLO                   BENIGN
# 53     P_00325  RIGHT  MLO                   BENIGN
# 54     P_00331   LEFT   CC                   BENIGN
# 55     P_00331   LEFT  MLO                   BENIGN
# 56     P_00344   LEFT   CC                   BENIGN
# 57     P_00344   LEFT  MLO                   BENIGN
# 58     P_00352   LEFT   CC                   BENIGN
# 59     P_00352   LEFT  MLO                   BENIGN
# 60     P_00353   LEFT   CC                   BENIGN
# 61     P_00353   LEFT  MLO                   BENIGN
# 62     P_00353   LEFT   CC                MALIGNANT
# 63     P_00353   LEFT  MLO                MALIGNANT
# 64     P_00368   LEFT   CC                   BENIGN
# 65     P_00368   LEFT  MLO                   BENIGN
# 66     P_00372  RIGHT   CC                MALIGNANT
# 67     P_00372  RIGHT  MLO                MALIGNANT
# 68     P_00390  RIGHT   CC                MALIGNANT
# 69     P_00390  RIGHT  MLO                MALIGNANT
# 70     P_00397   LEFT   CC                MALIGNANT
# 71     P_00402  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 72     P_00402  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 73     P_00403  RIGHT   CC                MALIGNANT
# 74     P_00403  RIGHT  MLO                MALIGNANT
# 75     P_00460   LEFT   CC                   BENIGN
# 76     P_00460   LEFT  MLO                   BENIGN
# 77     P_00466   LEFT  MLO                MALIGNANT
# 78     P_00485   LEFT   CC                MALIGNANT
# 79     P_00485   LEFT   CC                MALIGNANT
# 80     P_00485   LEFT   CC                MALIGNANT
# 81     P_00485   LEFT   CC                MALIGNANT
# 82     P_00485   LEFT   CC                MALIGNANT
# 83     P_00485   LEFT  MLO                MALIGNANT
# 84     P_00495  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 85     P_00495  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 86     P_00495  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 87     P_00495  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 88     P_00497   LEFT   CC                MALIGNANT
# 89     P_00497   LEFT  MLO                MALIGNANT
# 90     P_00537  RIGHT  MLO                MALIGNANT
# 91     P_00562   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 92     P_00562   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 93     P_00562   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 94     P_00562   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 95     P_00562  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 96     P_00562  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 97     P_00570   LEFT  MLO                MALIGNANT
# 98     P_00579   LEFT  MLO                   BENIGN
# 99     P_00589   LEFT   CC                   BENIGN
# 100    P_00589   LEFT  MLO                   BENIGN
# 101    P_00608   LEFT   CC                   BENIGN
# 102    P_00608   LEFT  MLO                   BENIGN
# 103    P_00620   LEFT   CC                   BENIGN
# 104    P_00643   LEFT   CC                MALIGNANT
# 105    P_00643   LEFT  MLO                MALIGNANT
# 106    P_00646   LEFT   CC                MALIGNANT
# 107    P_00646   LEFT  MLO                MALIGNANT
# 108    P_00649   LEFT   CC                   BENIGN
# 109    P_00649   LEFT  MLO                   BENIGN
# 110    P_00663  RIGHT   CC                   BENIGN
# 111    P_00663  RIGHT  MLO                   BENIGN
# 112    P_00678   LEFT   CC                MALIGNANT
# 113    P_00679   LEFT   CC                   BENIGN
# 114    P_00679   LEFT  MLO                   BENIGN
# 115    P_00681   LEFT   CC                MALIGNANT
# 116    P_00681   LEFT  MLO                MALIGNANT
# 117    P_00686  RIGHT  MLO                MALIGNANT
# 118    P_00723   LEFT  MLO                   BENIGN
# 119    P_00723   LEFT  MLO                   BENIGN
# 120    P_00723   LEFT  MLO                   BENIGN
# 121    P_00753   LEFT   CC                   BENIGN
# 122    P_00753   LEFT  MLO                   BENIGN
# 123    P_00774  RIGHT   CC                   BENIGN
# 124    P_00774  RIGHT  MLO                   BENIGN
# 125    P_00789   LEFT  MLO                   BENIGN
# 126    P_00790  RIGHT   CC                   BENIGN
# 127    P_00790  RIGHT  MLO                   BENIGN
# 128    P_00795   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 129    P_00795   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 130    P_00811   LEFT   CC                   BENIGN
# 131    P_00827  RIGHT   CC                MALIGNANT
# 132    P_00827  RIGHT  MLO                MALIGNANT
# 133    P_00843  RIGHT   CC                   BENIGN
# 134    P_00843  RIGHT  MLO                   BENIGN
# 135    P_00857  RIGHT   CC                MALIGNANT
# 136    P_00857  RIGHT  MLO                MALIGNANT
# 137    P_00876   LEFT   CC                MALIGNANT
# 138    P_00876   LEFT  MLO                MALIGNANT
# 139    P_00879  RIGHT   CC                MALIGNANT
# 140    P_00879  RIGHT  MLO                MALIGNANT
# 141    P_00905  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 142    P_00905  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 143    P_00906   LEFT   CC                MALIGNANT
# 144    P_00906   LEFT  MLO                MALIGNANT
# 145    P_00906   LEFT  MLO                MALIGNANT
# 146    P_00919  RIGHT   CC                MALIGNANT
# 147    P_00919  RIGHT  MLO                MALIGNANT
# 148    P_00974  RIGHT   CC                MALIGNANT
# 149    P_00974  RIGHT  MLO                MALIGNANT
# 150    P_01004   LEFT   CC                   BENIGN
# 151    P_01004   LEFT   CC                   BENIGN
# 152    P_01004   LEFT  MLO                   BENIGN
# 153    P_01004   LEFT  MLO                   BENIGN
# 154    P_01006   LEFT   CC                   BENIGN
# 155    P_01006   LEFT  MLO                   BENIGN
# 156    P_01022   LEFT   CC                   BENIGN
# 157    P_01022   LEFT  MLO                   BENIGN
# 158    P_01030  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 159    P_01030  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 160    P_01030  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 161    P_01030  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 162    P_01042  RIGHT   CC                   BENIGN
# 163    P_01042  RIGHT  MLO                   BENIGN
# 164    P_01050   LEFT  MLO                MALIGNANT
# 165    P_01058   LEFT   CC                MALIGNANT
# 166    P_01058   LEFT  MLO                MALIGNANT
# 167    P_01067   LEFT   CC                MALIGNANT
# 168    P_01067   LEFT  MLO                MALIGNANT
# 169    P_01092   LEFT   CC                MALIGNANT
# 170    P_01092   LEFT  MLO                MALIGNANT
# 171    P_01132  RIGHT  MLO                   BENIGN
# 172    P_01148  RIGHT  MLO                MALIGNANT
# 173    P_01152  RIGHT   CC                   BENIGN
# 174    P_01152  RIGHT  MLO                   BENIGN
# 175    P_01154   LEFT   CC                MALIGNANT
# 176    P_01154   LEFT  MLO                MALIGNANT
# 177    P_01157  RIGHT   CC                MALIGNANT
# 178    P_01157  RIGHT  MLO                MALIGNANT
# 179    P_01179   LEFT  MLO                MALIGNANT
# 180    P_01211   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 181    P_01211   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 182    P_01211  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 183    P_01211  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 184    P_01211  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 185    P_01211  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 186    P_01217  RIGHT   CC                MALIGNANT
# 187    P_01217  RIGHT  MLO                MALIGNANT
# 188    P_01224  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 189    P_01224  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 190    P_01237   LEFT   CC                   BENIGN
# 191    P_01237   LEFT  MLO                   BENIGN
# 192    P_01253  RIGHT   CC                MALIGNANT
# 193    P_01253  RIGHT  MLO                MALIGNANT
# 194    P_01272   LEFT   CC                   BENIGN
# 195    P_01272   LEFT   CC                   BENIGN
# 196    P_01272   LEFT  MLO                   BENIGN
# 197    P_01272   LEFT  MLO                   BENIGN
# 198    P_01303   LEFT   CC                MALIGNANT
# 199    P_01303   LEFT  MLO                MALIGNANT
# 200    P_01308   LEFT  MLO                   BENIGN
# 201    P_01318   LEFT  MLO                   BENIGN
# 202    P_01320   LEFT  MLO                   BENIGN
# 203    P_01352   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 204    P_01352   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 205    P_01353   LEFT   CC                   BENIGN
# 206    P_01353   LEFT  MLO                   BENIGN
# 207    P_01390  RIGHT   CC                MALIGNANT
# 208    P_01390  RIGHT   CC                MALIGNANT
# 209    P_01390  RIGHT  MLO                MALIGNANT
# 210    P_01390  RIGHT  MLO                MALIGNANT
# 211    P_01399  RIGHT   CC                   BENIGN
# 212    P_01399  RIGHT  MLO                   BENIGN
# 213    P_01407   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 214    P_01407   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 215    P_01407  RIGHT   CC                   BENIGN
# 216    P_01407  RIGHT  MLO                   BENIGN
# 217    P_01414  RIGHT   CC                   BENIGN
# 218    P_01414  RIGHT  MLO                   BENIGN
# 219    P_01415  RIGHT  MLO                   BENIGN
# 220    P_01419   LEFT   CC                MALIGNANT
# 221    P_01419   LEFT  MLO                MALIGNANT
# 222    P_01425   LEFT   CC                MALIGNANT
# 223    P_01425   LEFT  MLO                MALIGNANT
# 224    P_01460   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 225    P_01460   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 226    P_01460   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 227    P_01460  RIGHT   CC  BENIGN_WITHOUT_CALLBACK
# 228    P_01460  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 229    P_01460  RIGHT  MLO  BENIGN_WITHOUT_CALLBACK
# 230    P_01465   LEFT  MLO                   BENIGN
# 231    P_01471  RIGHT   CC                MALIGNANT
# 232    P_01471  RIGHT  MLO                MALIGNANT
# 233    P_01476  RIGHT   CC                   BENIGN
# 234    P_01476  RIGHT  MLO                   BENIGN
# 235    P_01483   LEFT   CC                MALIGNANT
# 236    P_01483   LEFT  MLO                MALIGNANT
# 237    P_01490   LEFT   CC                   BENIGN
# 238    P_01490   LEFT  MLO                   BENIGN
# 239    P_01502   LEFT   CC                MALIGNANT
# 240    P_01502   LEFT  MLO                MALIGNANT
# 241    P_01523   LEFT  MLO                   BENIGN
# 242    P_01534   LEFT   CC                MALIGNANT
# 243    P_01534   LEFT  MLO                MALIGNANT
# 244    P_01535   LEFT   CC                   BENIGN
# 245    P_01535   LEFT  MLO                   BENIGN
# 246    P_01536  RIGHT   CC                MALIGNANT
# 247    P_01536  RIGHT  MLO                MALIGNANT
# 248    P_01538  RIGHT  MLO                MALIGNANT
# 249    P_01538  RIGHT  MLO                MALIGNANT
# 250    P_01547   LEFT   CC                   BENIGN
# 251    P_01547   LEFT  MLO                   BENIGN
# 252    P_01562   LEFT   CC                   BENIGN
# 253    P_01562   LEFT  MLO                   BENIGN
# 254    P_01602  RIGHT   CC                MALIGNANT
# 255    P_01621   LEFT   CC                   BENIGN
# 256    P_01621   LEFT  MLO                   BENIGN
# 257    P_01635  RIGHT   CC                MALIGNANT
# 258    P_01635  RIGHT  MLO                MALIGNANT
# 259    P_01643   LEFT   CC                   BENIGN
# 260    P_01643   LEFT  MLO                   BENIGN
# 261    P_01643  RIGHT   CC                   BENIGN
# 262    P_01643  RIGHT  MLO                   BENIGN
# 263    P_01670   LEFT   CC                MALIGNANT
# 264    P_01670   LEFT  MLO                MALIGNANT
# 265    P_01670   LEFT  MLO                MALIGNANT
# 266    P_01670   LEFT  MLO                MALIGNANT
# 267    P_01711  RIGHT   CC                   BENIGN
# 268    P_01711  RIGHT  MLO                   BENIGN
# 269    P_01713  RIGHT  MLO                   BENIGN
# 270    P_01728   LEFT   CC                   BENIGN
# 271    P_01743  RIGHT   CC                MALIGNANT
# 272    P_01743  RIGHT  MLO                MALIGNANT
# 273    P_01752   LEFT   CC                   BENIGN
# 274    P_01752   LEFT  MLO                   BENIGN
# 275    P_01773  RIGHT   CC                   BENIGN
# 276    P_01773  RIGHT  MLO                   BENIGN
# 277    P_01803  RIGHT   CC                MALIGNANT
# 278    P_01803  RIGHT  MLO                MALIGNANT
# 279    P_01820   LEFT  MLO                   BENIGN
# 280    P_01834   LEFT  MLO                MALIGNANT
# 281    P_01842   LEFT  MLO                MALIGNANT
# 282    P_01845  RIGHT   CC                   BENIGN
# 283    P_01845  RIGHT   CC                   BENIGN
# 284    P_01845  RIGHT  MLO                   BENIGN
# 285    P_01845  RIGHT  MLO                   BENIGN
# 286    P_01861   LEFT   CC                MALIGNANT
# 287    P_01861   LEFT  MLO                MALIGNANT
# 288    P_01867   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 289    P_01867   LEFT   CC  BENIGN_WITHOUT_CALLBACK
# 290    P_01867   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 291    P_01867   LEFT  MLO  BENIGN_WITHOUT_CALLBACK
# 292    P_01868   LEFT   CC                   BENIGN
# 293    P_01868   LEFT  MLO                   BENIGN
# 294    P_01872   LEFT   CC                   BENIGN
# 295    P_01872   LEFT  MLO                   BENIGN
# 296    P_01882   LEFT   CC                   BENIGN
# 297    P_01882   LEFT  MLO                   BENIGN
# 298    P_01883  RIGHT   CC                MALIGNANT
# 299    P_01883  RIGHT  MLO                MALIGNANT
# 300    P_02102   LEFT   CC                MALIGNANT
# 301    P_02102   LEFT  MLO                MALIGNANT
# 302    P_02139   LEFT   CC                MALIGNANT
# 303    P_02139   LEFT  MLO                MALIGNANT
# 304    P_02153  RIGHT   CC                   BENIGN
# 305    P_02153  RIGHT  MLO                   BENIGN
# 306    P_02159   LEFT   CC                   BENIGN
# 307    P_02159   LEFT  MLO                   BENIGN
# 308    P_02176  RIGHT   CC                MALIGNANT
# 309    P_02176  RIGHT  MLO                MALIGNANT
# 310    P_02198   LEFT   CC                MALIGNANT
# 311    P_02198   LEFT  MLO                MALIGNANT
# 312    P_02275   LEFT   CC                MALIGNANT
# 313    P_02275   LEFT  MLO                MALIGNANT
# 314    P_02418  RIGHT   CC                MALIGNANT
# 315    P_02418  RIGHT  MLO                MALIGNANT
# 316    P_02420  RIGHT   CC                MALIGNANT
# 317    P_02420  RIGHT  MLO                MALIGNANT
# 318    P_02432   LEFT   CC                MALIGNANT
# 319    P_02432   LEFT  MLO                MALIGNANT
# 320    P_02464  RIGHT   CC                MALIGNANT
# 321    P_02464  RIGHT  MLO                MALIGNANT
# 322    P_02498  RIGHT   CC                   BENIGN
# 323    P_02498  RIGHT  MLO                   BENIGN
# 324    P_02501  RIGHT   CC                MALIGNANT
# 325    P_02501  RIGHT  MLO                MALIGNANT

# %%
df[df['patient_id'] == 'P_00038']

# %%
df.pathology.unique()

# %%
'Calc-Test_P_00038_LEFT_CC

# %%
im = Image.open('/mnt/disks/patches/cbis-ddsm/calc_test_full_roi_images/Calc-Test_P_00038_LEFT_CC_1_mask.png')

# %%
np.asarray(im).shape

# %%
roi = get_patches(np.asarray(im), step_size=100)

# %%
roi.shape

# %%
for number, roi_patch in enumerate(roi):
    print(number, roi_patch.mean())

# %%
for number, image in enumerate(ro):i
    image = normalize(image)
    cv2.imwrite(path + '_' + str(number) + '.png', image, [cv2.IMWRITE_PNG_COMPRESSION, 0])

# %%
x = np.mean(roi, axis=(1,2)) + 3

# %%
final_results = x-np.argmax(results, axis=-1)

# %%
for number, result in enumerate(final_results):
    print (number, result)
